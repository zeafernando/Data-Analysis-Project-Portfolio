# %%
#Importing libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# **0. Data reading and cleaning**

# %%
#Reading the dataset
df = pd.read_csv('CO2_Emissions_1960-2018.csv')

#Defining the countries
country = df[df.columns[0]]

#Selecting the values from 2000 to 2018
years = df[df.columns[41:,]]

#Making a dataframe with emissions by country since 2000 to 2018
df_2 =  pd.concat([country, years], axis=1)
df_2.head()
# Out:
#                   Country Name      2000      2001      2002      2003  \
# 0                        Aruba       NaN       NaN       NaN       NaN
# 1  Africa Eastern and Southern  0.900399  0.971981  0.975749  1.009963
# 2                  Afghanistan  0.037055  0.037488  0.048671  0.057008
# 3   Africa Western and Central  0.447244  0.474140  0.474875  0.474592
# 4                       Angola  0.754476  0.761843  0.777423  0.993848
#
#        2004      2005      2006      2007      2008      2009      2010  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  1.057182  1.032998  1.023646  1.045968  1.086449  1.021954  1.048876
# 2  0.045700  0.063927  0.073393  0.087083  0.158356  0.211306  0.297065
# 3  0.474318  0.509458  0.487953  0.475148  0.475025  0.426770  0.472819
# 4  1.028354  0.937037  1.009434  1.123635  1.155993  1.205902  1.221515
#
#        2011      2012      2013      2014      2015      2016      2017  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  1.005338  1.021646  1.031833  1.041145  0.987393  0.971016  0.959978
# 2  0.407074  0.335351  0.263716  0.234037  0.232176  0.208857  0.203328
# 3  0.497023  0.490867  0.504655  0.507671  0.480743  0.472959  0.476438
# 4  1.216317  1.204799  1.261542  1.285365  1.260921  1.227703  1.034317
#
#        2018
# 0       NaN
# 1  0.933541
# 2  0.200151
# 3  0.515544
# 4  0.887380

# %%
#Checking the dataframe to look for countries with NaN Values
df_2.info()

#Countries without CO2 emissions information since 2000 to 2018
countries_nan_value = df_2[df_2.isna().any(axis=1)]
countries_no_info = countries_nan_value[countries_nan_value.columns[0]].tolist()
countries_no_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   2000          239 non-null    float64
#  2   2001          239 non-null    float64
#  3   2002          239 non-null    float64
#  4   2003          239 non-null    float64
#  5   2004          239 non-null    float64
#  6   2005          239 non-null    float64
#  7   2006          239 non-null    float64
#  8   2007          239 non-null    float64
#  9   2008          239 non-null    float64
#  10  2009          239 non-null    float64
#  11  2010          239 non-null    float64
#  12  2011          239 non-null    float64
#  13  2012          239 non-null    float64
#  14  2013          239 non-null    float64
#  15  2014          239 non-null    float64
#  16  2015          239 non-null    float64
#  17  2016          239 non-null    float64
#  18  2017          239 non-null    float64
#  19  2018          239 non-null    float64
# dtypes: float64(19), object(1)
# memory usage: 41.7+ KB
# ['Aruba',
#  'American Samoa',
#  'Bermuda',
#  'Channel Islands',
#  'Curacao',
#  'Cayman Islands',
#  'Faroe Islands',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  'Hong Kong SAR, China',
#  'Isle of Man',
#  'Not classified',
#  'Macao SAR, China',
#  'St. Martin (French part)',
#  'Monaco',
#  'Northern Mariana Islands',
#  'New Caledonia',
#  'Puerto Rico',
#  'West Bank and Gaza',
#  'French Polynesia',
#  'San Marino',
#  'Sint Maarten (Dutch part)',
#  'Turks and Caicos Islands',
#  'British Virgin Islands',
#  'Virgin Islands (U.S.)',
#  'Kosovo']

# %%
#Cleaning the dataframe
clean_df = df_2.dropna()
clean_df.head(10)
# Out:
#                    Country Name       2000       2001       2002       2003  \
# 1   Africa Eastern and Southern   0.900399   0.971981   0.975749   1.009963
# 2                   Afghanistan   0.037055   0.037488   0.048671   0.057008
# 3    Africa Western and Central   0.447244   0.474140   0.474875   0.474592
# 4                        Angola   0.754476   0.761843   0.777423   0.993848
# 5                       Albania   1.026213   1.052228   1.229101   1.352144
# 6                       Andorra   7.952286   7.721549   7.566240   7.242416
# 7                    Arab World   3.163305   3.282509   3.347227   3.361728
# 8          United Arab Emirates  26.974535  29.145656  28.205380  27.891143
# 9                     Argentina   3.577628   3.349909   3.117425   3.370102
# 10                      Armenia   1.159761   1.180062   1.028354   1.159732
#
#          2004       2005       2006       2007       2008       2009  \
# 1    1.057182   1.032998   1.023646   1.045968   1.086449   1.021954
# 2    0.045700   0.063927   0.073393   0.087083   0.158356   0.211306
# 3    0.474318   0.509458   0.487953   0.475148   0.475025   0.426770
# 4    1.028354   0.937037   1.009434   1.123635   1.155993   1.205902
# 5    1.417273   1.351492   1.353362   1.420867   1.414848   1.475652
# 6    7.344262   7.353780   6.790543   6.531047   6.439304   6.156688
# 7    3.474240   3.704298   3.801646   3.883140   4.093538   4.193272
# 8   27.031564  25.343150  22.916237  21.347591  22.032627  19.852557
# 9    3.685184   3.762124   3.954454   4.123293   4.195343   3.889060
# 10   1.253035   1.496011   1.517763   1.773161   1.956930   1.561584
#
#          2010       2011       2012       2013       2014       2015  \
# 1    1.048876   1.005338   1.021646   1.031833   1.041145   0.987393
# 2    0.297065   0.407074   0.335351   0.263716   0.234037   0.232176
# 3    0.472819   0.497023   0.490867   0.504655   0.507671   0.480743
# 4    1.221515   1.216317   1.204799   1.261542   1.285365   1.260921
# 5    1.572251   1.734823   1.579092   1.654524   1.806789   1.759987
# 6    6.157198   5.850886   5.944654   5.942801   5.807128   6.026182
# 7    4.322002   4.308741   4.512189   4.495194   4.600191   4.617964
# 8   19.043279  18.589933  19.223116  20.015421  19.951852  20.948092
# 9    4.122245   4.296015   4.277882   4.359886   4.216361   4.314434
# 10   1.508351   1.717343   1.983192   1.898127   1.881608   1.825292
#
#          2016       2017       2018
# 1    0.971016   0.959978   0.933541
# 2    0.208857   0.203328   0.200151
# 3    0.472959   0.476438   0.515544
# 4    1.227703   1.034317   0.887380
# 5    1.714126   1.948872   1.939732
# 6    6.080600   6.104134   5.973405
# 7    4.570308   4.528351   4.438716
# 8   21.307610  21.950614  20.797498
# 9    4.227539   4.089472   3.987234
# 10   1.726753   1.806581   1.880246

# %%
#Transforming the dataset to the format Country, Year, CO2
Year_list = years.columns.tolist()
countries = clean_df[clean_df.columns[0]].tolist()
data = pd.DataFrame({'Country': [], 'Year': [], 'CO2': []})
for i in range(0,len(countries)):
    for i_y in range(0,len(Year_list)):
        data_i = pd.DataFrame({'Country': [countries[i]], 'Year': [int(Year_list[i_y])], 
                               'CO2': [clean_df[clean_df['Country Name']==countries[i]].iloc[0][i_y+1]]})
        data = data.append(data_i)
data.head()
# Out:
#                        Country    Year       CO2
# 0  Africa Eastern and Southern  2000.0  0.900399
# 0  Africa Eastern and Southern  2001.0  0.971981
# 0  Africa Eastern and Southern  2002.0  0.975749
# 0  Africa Eastern and Southern  2003.0  1.009963
# 0  Africa Eastern and Southern  2004.0  1.057182

# %% [markdown]
# **1. CO2 emissions by country over the years**

# %%
#Making dataframe interactive
idf = data.interactive()

# %%
#Define panel widgets 

#Year slider
year_slider = pn.widgets.IntSlider(name='Year slider', start=2000, end=2018, step=1, value=2000)

#Country button
country_button = pn.widgets.Select(name='Select country or region', options=countries)

# %%
year_slider
# Out:
# IntSlider(end=2018, name='Year slider', start=2000, value=2000)

# %%
country_button
# Out:
# Select(options=['Africa Eastern and South...], value='Africa Eastern a...)

# %%
#Pipeline for the CO2 emissions since 2000 to 2018 per country
co2_pipeline = (
    idf[
        (idf.Country == country_button)
    ]
    .groupby(['Year'])['CO2'].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)

#CO2 emissions plot
co2_plot = co2_pipeline.hvplot(x='Year',y='CO2',title='CO2 Emissions from 2000 to 2018',
                               ylabel='CO2 [metric tons per capita]')
co2_plot
# Out:
# <div id='1007'>
#   <div class="bk-root" id="32398af4-8659-4c38-855f-653aa7ee5b41" data-root-id="1007"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"c5e92269-ca83-4e32-ae1d-d034c70fe658":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"axis":{"id":"1029"},"coordinates":null,"dimension":1,"grid_line_color":null,"group":null,"ticker":null},"id":"1032","type":"Grid"},{"attributes":{"below":[{"id":"1025"}],"center":[{"id":"1028"},{"id":"1032"}],"height":300,"left":[{"id":"1029"}],"margin":[5,5,5,5],"min_border_bottom":10,"min_border_left":10,"min_border_right":10,"min_border_top":10,"renderers":[{"id":"1052"}],"sizing_mode":"fixed","title":{"id":"1017"},"toolbar":{"id":"1039"},"width":700,"x_range":{"id":"1013"},"x_scale":{"id":"1021"},"y_range":{"id":"1014"},"y_scale":{"id":"1023"}},"id":"1016","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1059","type":"BasicTickFormatter"},{"attributes":{"client_comm_id":"f9d0d11c958849f39bebf0281543af27","comm_id":"ab367554236d4f4eace2c4ce11fc6ca3","plot_id":"1007"},"id":"1105","type":"panel.models.comm_manager.CommManager"},{"attributes":{"line_alpha":0.1,"line_color":"#30a2da","line_width":2,"x":{"field":"Year"},"y":{"field":"CO2"}},"id":"1050","type":"Line"},{"attributes":{},"id":"1056","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Year","coordinates":null,"formatter":{"id":"1056"},"group":null,"major_label_policy":{"id":"1057"},"ticker":{"id":"1026"}},"id":"1025","type":"LinearAxis"},{"attributes":{"margin":[5,10,5,10],"options":["Africa Eastern and Southern","Afghanistan","Africa Western and Central","Angola","Albania","Andorra","Arab World","United Arab Emirates","Argentina ...

# %% [markdown]
# **2. Countries with max CO2 emissions level per year**

# %%
#Pipeline with the 5 countries with the highest CO2 emissions per year
largest_co2_pipeline = (
    idf[
        (idf.Year == year_slider)
    ]
    .groupby(['Country'])['CO2'].sum().nlargest()
    .to_frame()
    .reset_index()
    .sort_values(by='CO2')
    .reset_index(drop=True)
)

#Top 5 countries plot
larg_co2_plot = largest_co2_pipeline.hvplot(
    kind = 'bar',
    x = 'Country',
    y = 'CO2',
    title = '5 countries with the highest CO2 emissiones per year',
    ylabel='CO2 [metric tons per capita]'
)

larg_co2_plot
# Out:
# <div id='1156'>
#   <div class="bk-root" id="df8095ac-2b0a-4ed6-af1f-62bb98073ef8" data-root-id="1156"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e043f9ce-f9f5-44c5-84e0-c881294d8589":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"source":{"id":"1194"}},"id":"1201","type":"CDSView"},{"attributes":{"overlay":{"id":"1186"}},"id":"1184","type":"BoxZoomTool"},{"attributes":{},"id":"1183","type":"WheelZoomTool"},{"attributes":{},"id":"1204","type":"CategoricalTickFormatter"},{"attributes":{"children":[{"id":"1159"},{"id":"1161"}],"margin":[0,0,0,0],"name":"Row01622"},"id":"1158","type":"Row"},{"attributes":{"client_comm_id":"ab8b9c055c3148f497d3c92935874118","comm_id":"f13da3f9aacc406eb48799607ea42cae","plot_id":"1156"},"id":"1253","type":"panel.models.comm_manager.CommManager"},{"attributes":{"active_drag":{"id":"1182"},"active_scroll":{"id":"1183"},"tools":[{"id":"1164"},{"id":"1181"},{"id":"1182"},{"id":"1183"},{"id":"1184"},{"id":"1185"}]},"id":"1187","type":"Toolbar"},{"attributes":{},"id":"1175","type":"CategoricalTicker"},{"attributes":{"data":{"CO2":{"__ndarray__":"ljR6m9B4NECx3v5rixA3QNVq+VDK5DdAOvJHIHv5OkDiTFbLrFZCQA==","dtype":"float64","order":"little","shape":[5]},"Country":["United States","Kuwait","Bahrain","United Arab Emirates","Qatar"]},"selected":{"id":"1195"},"selection_policy":{"id":"1220"}},"id":"1194","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"1174"}],"center":[{"id":"1176"},{"id":"1180"}],"height":300,"left":[{"id":"1177"}],"margin":[5,5,5,5],"min_border_bottom":10,"min_border_left":10,"min_border_right":10,"min_border_top":10,"renderers":[{"id":"1200"}],"sizing_mode":"fixed","title":{"id":"1166" ...

# %% [markdown]
# **3. Countries with min CO2 emissions level per year**

# %%
#Pipeline with the 5 countries with the highest CO2 emissions per year
lowest_co2_pipeline = (
    idf[
        (idf.Year == year_slider)
    ]
    .groupby(['Country'])['CO2'].sum().nsmallest()
    .to_frame()
    .reset_index()
    .sort_values(by='CO2')
    .reset_index(drop=True)
)

#Top 5 countries plot
low_co2_plot = lowest_co2_pipeline.hvplot(
    kind = 'bar',
    x = 'Country',
    y = 'CO2',
    title = '5 countries with the lowest CO2 emissiones per year',
    ylabel='CO2 [metric tons per capita]'
)

low_co2_plot
# Out:
# <div id='1304'>
#   <div class="bk-root" id="928642e6-b20c-417c-b814-e1a3e38bf86d" data-root-id="1304"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"35cf94e6-6118-4675-ae32-2b6bbeeba876":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"overlay":{"id":"1334"}},"id":"1332","type":"BoxZoomTool"},{"attributes":{},"id":"1368","type":"UnionRenderers"},{"attributes":{"below":[{"id":"1322"}],"center":[{"id":"1324"},{"id":"1328"}],"height":300,"left":[{"id":"1325"}],"margin":[5,5,5,5],"min_border_bottom":10,"min_border_left":10,"min_border_right":10,"min_border_top":10,"renderers":[{"id":"1348"}],"sizing_mode":"fixed","title":{"id":"1314"},"toolbar":{"id":"1335"},"width":700,"x_range":{"id":"1310"},"x_scale":{"id":"1318"},"y_range":{"id":"1311"},"y_scale":{"id":"1320"}},"id":"1313","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1333","type":"ResetTool"},{"attributes":{},"id":"1330","type":"PanTool"},{"attributes":{},"id":"1326","type":"BasicTicker"},{"attributes":{"axis_label":"CO2 [metric tons per capita]","coordinates":null,"formatter":{"id":"1355"},"group":null,"major_label_policy":{"id":"1356"},"ticker":{"id":"1326"}},"id":"1325","type":"LinearAxis"},{"attributes":{"callback":null,"renderers":[{"id":"1348"}],"tags":["hv_created"],"tooltips":[["Country","@{Country}"],["CO2","@{CO2}"]]},"id":"1312","type":"HoverTool"},{"attributes":{"coordinates":null,"data_source":{"id":"1342"},"glyph":{"id":"1345"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"1347"},"nonselection_glyph":{"id":"1346"},"selection_glyph":{"id":"1350"},"view":{"id":"1349"}},"id":"1348","type":"GlyphRenderer"},{"attributes":{"axis":{"id":"1325"},"coordinates": ...

# %% [markdown]
# **4. Top (highest and lowest) countries tables**

# %%
max_CO2_table = largest_co2_pipeline.pipe(pn.widgets.Tabulator, pagination = 'remote',
                                     page_size = 10, sizing_mode = 'stretch_width')
max_CO2_table
# Out:
# <div id='1452'>
#   <div class="bk-root" id="8f020ffc-04b3-4d34-9902-1ef2b60841c3" data-root-id="1452"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"a8872977-f6fd-4320-b96b-49ef147b3d43":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1456"}],"margin":[0,0,0,0],"name":"Column02247"},"id":"1455","type":"Column"},{"attributes":{"columns":[{"id":"1464"},{"id":"1469"},{"id":"1474"}],"configuration":{"columns":[{"field":"index","sorter":"number"},{"field":"Country"},{"field":"CO2","sorter":"number"}],"dataTree":false,"selectable":true},"indexes":["index"],"layout":"fit_data_table","margin":[5,10,5,10],"max_page":1,"name":"","page":1,"page_size":10,"pagination":"remote","select_mode":true,"selectable_rows":null,"sizing_mode":"stretch_width","source":{"id":"1459"},"styles":{"data":{},"id":"eb0a8260c30f4ad09f0c7995a396cc2e"},"subscribed_events":["cell-click","table-edit"],"theme_url":"https://cdn.jsdelivr.net/npm/@holoviz/panel@0.14.3/dist/bundled/datatabulator/tabulator-tables@5.3.2/dist/css/"},"id":"1477","type":"panel.models.tabulator.DataTabulator"},{"attributes":{"editor":{"id":"1468"},"field":"Country","formatter":{"id":"1467"},"title":"Country","width":0},"id":"1469","type":"TableColumn"},{"attributes":{"children":[{"id":"1453"}],"margin":[0,0,0,0],"name":"Row02270"},"id":"1452","type":"Row"},{"attributes":{"children":[{"id":"1454"},{"id":"1458"}],"margin":[0,0,0,0],"name":"Column02269"},"id":"1453","type":"Column"},{"attributes":{"text_align":"left"},"id":"1461","type":"NumberFormatter"},{"attributes":{"editor":{"id":"1463"},"field":"index","formatter":{"id":"1461"},"title":"index","width":0},"id":"1464","type":"Tab ...
#     var render_items = [{"docid":"a8872977-f6fd-4320-b96b-49ef147b3d43","root_ids":["1452"],"roots":{"1452":"8f020ffc-04b3-4d34-9902-1ef2b60841c3"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
min_CO2_table = lowest_co2_pipeline.pipe(pn.widgets.Tabulator, pagination = 'remote',
                                     page_size = 10, sizing_mode = 'stretch_width')
min_CO2_table
# Out:
# <div id='1496'>
#   <div class="bk-root" id="ca9d5c6b-3ba5-4aa1-aa5b-5a28b671861e" data-root-id="1496"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"5b2c1bc5-7488-4bdd-ac2d-223c46edf2f0":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"end":2018,"margin":[5,10,5,10],"start":2000,"title":"Year slider","value":2000},"id":"1500","type":"Slider"},{"attributes":{},"id":"1507","type":"CellEditor"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer02321","sizing_mode":"stretch_width"},"id":"1501","type":"Spacer"},{"attributes":{},"id":"1523","type":"UnionRenderers"},{"attributes":{"client_comm_id":"99fc7290fd69485b905a0eb9b5f3487a","comm_id":"69642d40ead443dd917ddc22abcf7660","plot_id":"1496"},"id":"1529","type":"panel.models.comm_manager.CommManager"},{"attributes":{},"id":"1517","type":"NumberEditor"},{"attributes":{"text_align":"left"},"id":"1505","type":"NumberFormatter"},{"attributes":{"format":"0,0.0[00000]","text_align":"right"},"id":"1516","type":"NumberFormatter"},{"attributes":{},"id":"1511","type":"StringFormatter"},{"attributes":{"data":{"CO2":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA94yKFM3/kz890Sxe3fiiPw==","dtype":"float64","order":"little","shape":[5]},"Country":["Montenegro","South Sudan","Timor-Leste","Congo, Dem. Rep.","Afghanistan"],"index":[0,1,2,3,4]},"selected":{"id":"1504"},"selection_policy":{"id":"1523"}},"id":"1503","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"1500"}],"margin":[0,0,0,0],"name":"Column02301"},"id":"1499","type":"Column"},{"attributes":{"children":[{"id":"1521"}],"margin":[0,0,0,0],"name":"Row02306","sizing_mode":"stretch_width"},"id":"1502","type":"Row"},{"attributes":{"childre ...
#     var render_items = [{"docid":"5b2c1bc5-7488-4bdd-ac2d-223c46edf2f0","root_ids":["1496"],"roots":{"1496":"ca9d5c6b-3ba5-4aa1-aa5b-5a28b671861e"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# **5. Geomap plot for the CO2 emissions over the years**

# %%
import plotly.express as px

#Reading the dataframe with countries available with iso_alpha and iso_num
df_countries= px.data.gapminder()

#Getting a lists of countries available in the dataframe
av_countries = df_countries['country'].unique().tolist()

#Creating a filter to match the countries in the main dataframe
filter1 = data['Country'].isin(av_countries)

#Creating the new dataframe
new_df = data[filter1]

#Indexing the iso code for the available countries

#Getting the exact country
filter2 = new_df['Country'].unique().tolist()

#Computing the iso code for every country
iso_code = pd.DataFrame({'iso_alpha': []})
for i in range(0,len(filter2)):
    for i_c in range (0,len(Year_list)):
        iso_count = df_countries[df_countries['country']==filter2[i]]['iso_alpha'].iloc[0]
        iso_code_i = pd.DataFrame({'iso_alpha': [iso_count]})
        iso_code = iso_code.append(iso_code_i)

#Indexing the iso codes in the dataframe
new_df['iso_alpha'] = iso_code.loc[0,:]

new_df.head(10)
# Out:
# C:\Users\zeama\AppData\Local\Temp\ipykernel_17420\588763341.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Country    Year       CO2 iso_alpha
# 0  Afghanistan  2000.0  0.037055       AFG
# 0  Afghanistan  2001.0  0.037488       AFG
# 0  Afghanistan  2002.0  0.048671       AFG
# 0  Afghanistan  2003.0  0.057008       AFG
# 0  Afghanistan  2004.0  0.045700       AFG
# 0  Afghanistan  2005.0  0.063927       AFG
# 0  Afghanistan  2006.0  0.073393       AFG
# 0  Afghanistan  2007.0  0.087083       AFG
# 0  Afghanistan  2008.0  0.158356       AFG
# 0  Afghanistan  2009.0  0.211306       AFG

# %%
pn.extension('plotly')

#Creating the geomap
fig = px.choropleth(new_df, locations="iso_alpha", color="CO2", hover_name="Country", 
                    animation_frame="Year", projection="natural earth", title='CO2 emissions in the world since 2000 to 2018',
                   width=600)

geo_pane = pn.pane.Plotly(fig)
#geo_pane.show()

# %% [markdown]
# **6. Creating Dashboard**

# %%
#Layout using template
template = pn.template.FastListTemplate(
    title = 'CO2 world emissions since 2000 to 2018',
    sidebar=[pn.pane.Markdown('# CO2 emissions over the years'),
            pn.pane.Markdown('Carbon dioxide (CO2) emissions began to rise more steeply from the 1950s, and by 2000 had reached 25.23 billion metric tons of CO2. Emissions soared 32 percent between 2000 and 2010.'),
            pn.pane.PNG('CO2 emissions photo.png', sizing_mode='scale_both'),
            pn.pane.Markdown('## Settings'),
            year_slider],
    main = [pn.Row(pn.Column(country_button,
                            co2_plot.panel(width=600), margin=(0,25)),
                  pn.Column(larg_co2_plot.panel(width=500)),
                  pn.Column(max_CO2_table.panel(width=400))),
           pn.Row(pn.Column(geo_pane),
                 pn.Column(low_co2_plot.panel(width=500), margin=(0,25)),
                 pn.Column(min_CO2_table.panel(width=400)))],
    accent_base_color = '#759EB8',
    header_background = '#759EB8',
)

#template.show()
template.servable();
